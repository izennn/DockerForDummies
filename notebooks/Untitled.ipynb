# %%
import OpenCV
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8e094c6253de> in <module>()
# ----> 1 import OpenCV
#
# ModuleNotFoundError: No module named 'OpenCV'

# %%
import cv2

# %%
print cv2.version
# Out:
#   File "<ipython-input-3-20b965ee503b>", line 1
#     print cv2.version
#             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(cv2.version)?

# %%
print (cv2.__version__)
# Out:
# 3.1.0

# %%
print('Hi')
# Out:
# Hi

# %%
import numpy as np

# %%
np.test()
# Out:
# Running unit tests for numpy
# NumPy version 1.14.3
# NumPy relaxed strides checking option: True
# NumPy is installed in /opt/conda/lib/python3.6/site-packages/numpy
# Python version 3.6.5 |Anaconda, Inc.| (default, Apr 29 2018, 16:14:56) [GCC 7.2.0]
# nose version 1.3.7
# ...

# %%
import cv2
